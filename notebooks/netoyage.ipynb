# %%
import pandas as pd
df = pd.read_csv("../data/raw/dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   titre             500 non-null    str
#  1   type_bien         500 non-null    str
#  2   type_annonce      500 non-null    str
#  3   prix              500 non-null    float64
#  4   surface_m2        500 non-null    int64
#  5   nb_chambres       152 non-null    float64
#  6   nb_salons         152 non-null    float64
#  7   nb_sdb            152 non-null    float64
#  8   quartier          500 non-null    str
#  9   ville             500 non-null    str
#  10  description       500 non-null    str
#  11  caracteristiques  60 non-null     str
#  12  seller            500 non-null    str
#  13  date_publication  500 non-null    str
#  14  url_annonce       500 non-null    str
#  15  source            500 non-null    str
# dtypes: float64(4), int64(1), str(11)
# memory usage: 62.6 KB
# ...

# %%
df.describe()
# Out:
#                prix    surface_m2  nb_chambres   nb_salons      nb_sdb
# count  5.000000e+02    500.000000   152.000000  152.000000  152.000000
# mean   5.577926e+06    429.558000     3.940789    1.421053    2.046053
# std    2.547861e+07    920.207874     3.657947    1.641863    1.497631
# min    3.500000e+03      1.000000     0.000000    0.000000    0.000000
# 25%    1.300000e+06    195.000000     1.750000    1.000000    1.000000
# 50%    3.100000e+06    300.000000     4.000000    1.000000    2.000000
# 75%    5.500000e+06    534.000000     5.000000    2.000000    3.000000
# max    5.500000e+08  16000.000000    25.000000   10.000000    7.000000
